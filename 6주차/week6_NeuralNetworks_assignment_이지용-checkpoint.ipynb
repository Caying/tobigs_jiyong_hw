# %%
from random import seed
from random import random
import numpy as np
 
# 네트워크 초기 설정
def initialize_network(n_inputs, n_hidden, n_outputs):
    network = list()
    hidden_layer = [{'weights':[random() for i in range(n_inputs + 1)]} for i in range(n_hidden)]
    network.append(hidden_layer)
    output_layer = [{'weights':[random() for i in range(n_hidden + 1)]} for i in range(n_outputs)]
    network.append(output_layer)
    return network
 
seed(1)
network = initialize_network(2, 1, 2)
for layer in network:
    print(layer)
# Out:
# [{'weights': [0.13436424411240122, 0.8474337369372327, 0.763774618976614]}]
# [{'weights': [0.2550690257394217, 0.49543508709194095]}, {'weights': [0.4494910647887381, 0.651592972722763]}]

# %%
def activate(weights, inputs):
    activation = weights[-1]
    for i in range(len(weights)-1):
        activation += weights[i] * inputs[i]  # 순전파 진행 
    return activation

def sigmoid(activation):
    return 1.0/(1.0+np.exp(-activation)) # 시그모이드 구현

def forward_propagate(network, row):
    inputs = row
    for layer in network:
        new_inputs = []
        for neuron in layer:
            activation = activate(neuron['weights'], inputs)  
            neuron['output'] = sigmoid(activation) # 나온 계산 값을 그대로 쓰나요?
            new_inputs.append(neuron['output']) # new_input은 다음 히든층에 들어갈 값이죠?
        inputs = new_inputs
    return inputs

# %% [markdown]
# **여기까지는 순전파 학습과정이었습니다. 이 과정이 끝나면 가중치가 바뀌나요?
# 답변을 답변의 근거 코딩 결과와 함께 보여주세요.**

# %%
network
# Out:
# [[{'weights': [0.13436424411240122, 0.8474337369372327, 0.763774618976614]}],
#  [{'weights': [0.2550690257394217, 0.49543508709194095]},
#   {'weights': [0.4494910647887381, 0.651592972722763]}]]

# %%
row = [1, 0, None]
output = forward_propagate(network, row)
print(output)
# Out:
# [0.6629970129852887, 0.7253160725279748]

# %%
def sigmoid_derivative(output):
    return output*(1-output) # 시그모이드 미분

def backward_propagate_error(network, expected):
    for i in reversed(range(len(network))):
        layer = network[i]
        errors = []
        if i != len(network)-1:
            for j in range(len(layer)):
                error = 0.0
                for neuron in network[i + 1]:
                    error += (neuron['weights'][j] * neuron['delta'])
                errors.append(error) 
        else:
            for j in range(len(layer)):
                neuron = layer[j]
                errors.append(expected[j]-neuron['output']) # 역전파시 오차는 어떻게 설정했나요?
        for j in range(len(layer)):
            neuron = layer[j]
            neuron['delta'] = errors[j] * sigmoid_derivative(neuron["output"]) # 시그모이드 함수를 사용한 역전파

# %%
expected = [0, 1]

backward_propagate_error(network, expected)
for layer in network:
    print(layer)
# Out:
# [{'weights': [0.13436424411240122, 0.8474337369372327, 0.763774618976614], 'output': 0.7105668883115941, 'delta': -0.002711797799238243}]
# [{'weights': [0.2550690257394217, 0.49543508709194095], 'output': 0.6629970129852887, 'delta': -0.14813473120687762}, {'weights': [0.4494910647887381, 0.651592972722763], 'output': 0.7253160725279748, 'delta': 0.05472601157879688}]

# %%
def weights_update(network, row, l_rate):
    for i in range(len(network)):
        inputs = row[:-1]
        if i != 0:
            inputs = [neuron['output'] for neuron in network[i - 1]]
        for neuron in network[i]:
            for j in range(len(inputs)):
                neuron['weights'][j] += l_rate * neuron['delta'] * inputs[j]
            neuron['weights'][-1] += l_rate * neuron['delta'] # 퍼셉트론 학습 규칙
            

def train_network(network, train, l_rate, n_epoch, n_outputs):
    for epoch in range(n_epoch):
        sum_error = 0
        for row in train:
            outputs = forward_propagate(network, row) # 순전파 
            expected = [0 for i in range(n_outputs)]
            expected[row[-1]] = 1
            sum_error += sum([(expected[i]) - outputs[i]**2 for i in range(len(expected))]) # 예측값의 오차 합
            backward_propagate_error(network, expected)
            weights_update(network, row, l_rate)
        print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))

# %%
seed(1)
dataset = [[2.7810836,2.550537003,0],
    [1.465489372,2.362125076,0],
    [3.396561688,4.400293529,0],
    [1.38807019,1.850220317,0],
    [3.06407232,3.005305973,0],
    [7.627531214,2.759262235,1],
    [5.332441248,2.088626775,1],
    [6.922596716,1.77106367,1],
    [8.675418651,-0.242068655,1],
    [7.673756466,3.508563011,1]]

# %%
n_inputs = len(dataset[0]) - 1 # 뉴럴렛의 입력노드로 뭐가 들어가죠? 그럼 입력 노드의 개수는?
n_outputs = len(set([dataset[i][-1] for i in range(len(dataset))])) # 뉴럴렛의 출력노드의 개수는 뭐라고 했죠? 
network = initialize_network(n_inputs, 2, n_outputs)

train_network(network, dataset, 0.1, 20000, n_outputs) # 자유롭게 설정하고 최적을 찾아보세요.

# 학습된(최적화)된 네트워크가 초기 네트워크와 달리 어떻게 변하였는지 출력하시오. (layer별로,hint : for문))
for layer in network:
    print(layer)
# Out:
# >epoch=0, lrate=0.100, error=-1.926
# >epoch=1, lrate=0.100, error=-1.167
# >epoch=2, lrate=0.100, error=-0.411
# >epoch=3, lrate=0.100, error=0.316
# >epoch=4, lrate=0.100, error=0.993
# >epoch=5, lrate=0.100, error=1.606
# >epoch=6, lrate=0.100, error=2.147
# >epoch=7, lrate=0.100, error=2.614
# >epoch=8, lrate=0.100, error=3.012
# >epoch=9, lrate=0.100, error=3.347
# >epoch=10, lrate=0.100, error=3.628
# >epoch=11, lrate=0.100, error=3.861
# >epoch=12, lrate=0.100, error=4.055
# >epoch=13, lrate=0.100, error=4.215
# >epoch=14, lrate=0.100, error=4.348
# >epoch=15, lrate=0.100, error=4.458
# >epoch=16, lrate=0.100, error=4.550
# >epoch=17, lrate=0.100, error=4.625
# >epoch=18, lrate=0.100, error=4.688
# >epoch=19, lrate=0.100, error=4.740
# >epoch=20, lrate=0.100, error=4.783
# >epoch=21, lrate=0.100, error=4.819
# >epoch=22, lrate=0.100, error=4.849
# >epoch=23, lrate=0.100, error=4.873
# >epoch=24, lrate=0.100, error=4.894
# >epoch=25, lrate=0.100, error=4.911
# >epoch=26, lrate=0.100, error=4.925
# >epoch=27, lrate=0.100, error=4.937
# >epoch=28, lrate=0.100, error=4.947
# >epoch=29, lrate=0.100, error=4.955
# >epoch=30, lrate=0.100, error=4.962
# >epoch=31, lrate=0.100, error=4.968
# >epoch=32, lrate=0.100, error=4.972
# >epoch=33, lrate=0.100, error=4.976
# >epoch=34, lrate=0.100, error=4.980
# >epoch=35, lrate=0.100, error=4.982
# >epoch=36, lrate=0.100, error=4.985
# >epoch=37, lrate=0.100, error=4.987
# >epoch=38, lrate=0.100, error=4.988
# >epoch=39, lrate=0.100, error=4.990
# >epoch=40, lrate=0.100, error=4.991
# >epoch=41, lrate=0.100, error=4.992
# >epoch=42, lrate=0.100, error=4.992
# >epoch=43, lrate=0.100, error=4.993
# >epoch=44, lrate=0.100, error=4.993
# >epoch=45, lrate=0.100, error=4.994
# >epoch=46, lrate=0.100, error=4.994
# >epoch=47, lrate=0.100, error=4.995
# >epoch=48, lrate=0.100, error=4.995
# >epoch=49, lrate=0.100, error=4.995
# >epoch=50, lrate=0.100, error=4.995
# >epoch=51, lrate=0.100, error=4.995
# >epoch=52, lrate=0.100, error=4.996
# >epoch=53, lrate=0.100, error=4.996
# >epoch=54, lrate=0.100, error=4.996
# >epoch=55, lrate=0.100, error=4.996
# >epoch=56, lrate=0.100, error=4.996
# >epoch=57, lrate=0.100, error=4.996
# >epoch=58, lrate=0.100, error=4.996
# >epoch=59, lrate=0.100, error=4.996
# >epoch=60, lrate=0.100, error=4.996
# >epoch=61, lrate=0.100, error=4.996
# >epoch=62, lrate=0.100, error=4.996
# >epoch=63, lrate=0.100, error=4.996
# >epoch=64, lrate=0.100, error=4.996
# >epoch=65, lrate=0.100, error=4.996
# >epoch=66, lrate=0.100, error=4.996
# >epoch=67, lrate=0.100, error=4.996
# >epoch=68, lrate=0.100, error=4.996
# >epoch=69, lrate=0.100, error=4.996
# >epoch=70, lrate=0.100, error=4.996
# >epoch=71, lrate=0.100, error=4.996
# >epoch=72, lrate=0.100, error=4.996
# >epoch=73, lrate=0.100, error=4.996
# >epoch=74, lrate=0.100, error=4.996
# >epoch=75, lrate=0.100, error=4.996
# >epoch=76, lrate=0.100, error=4.996
# >epoch=77, lrate=0.100, error=4.996
# >epoch=78, lrate=0.100, error=4.996
# >epoch=79, lrate=0.100, error=4.996
# >epoch=80, lrate=0.100, error=4.996
# >epoch=81, lrate=0.100, error=4.996
# >epoch=82, lrate=0.100, error=4.996
# >epoch=83, lrate=0.100, error=4.996
# >epoch=84, lrate=0.100, error=4.996
# >epoch=85, lrate=0.100, error=4.996
# >epoch=86, lrate=0.100, error=4.996
# >epoch=87, lrate=0.100, error=4.996
# >epoch=88, lrate=0.100, error=4.996
# >epoch=89, lrate=0.100, error=4.996
# >epoch=90, lrate=0.100, error=4.996
# >epoch=91, lrate=0.100, error=4.996
# >epoch=92, lrate=0.100, error=4.996
# >epoch=93, lrate=0.100, error=4.996
# >epoch=94, lrate=0.100, error=4.996
# >epoch=95, lrate=0.100, error=4.996
# >epoch=96, lrate=0.100, error=4.996
# >epoch=97, lrate=0.100, error=4.996
# >epoch=98, lrate=0.100, error=4.996
# >epoch=99, lrate=0.100, error=4.996
# >epoch=100, lrate=0.100, error=4.996
# >epoch=101, lrate=0.100, error=4.996
# >epoch=102, lrate=0.100, error=4.996
# >epoch=103, lrate=0.100, error=4.996
# >epoch=104, lrate=0.100, error=4.996
# >epoch=105, lrate=0.100, error=4.996
# >epoch=106, lrate=0.100, error=4.996
# >epoch=107, lrate=0.100, error=4.996
# >epoch=108, lrate=0.100, error=4.996
# >epoch=109, lrate=0.100, error=4.996
# >epoch=110, lrate=0.100, error=4.996
# >epoch=111, lrate=0.100, error=4.996
# >epoch=112, lrate=0.100, error=4.996
# >epoch=113, lrate=0.100, error=4.996
# >epoch=114, lrate=0.100, error=4.996
# >epoch=115, lrate=0.100, error=4.996
# >epoch=116, lrate=0.100, error=4.996
# >epoch=117, lrate=0.100, error=4.996
# >epoch=118, lrate=0.100, error=4.996
# >epoch=119, lrate=0.100, error=4.996
# >epoch=120, lrate=0.100, error=4.996
# >epoch=121, lrate=0.100, error=4.996
# >epoch=122, lrate=0.100, error=4.996
# >epoch=123, lrate=0.100, error=4.996
# >epoch=124, lrate=0.100, error=4.996
# >epoch=125, lrate=0.100, error=4.996
# >epoch=126, lrate=0.100, error=4.996
# >epoch=127, lrate=0.100, error=4.996
# >epoch=128, lrate=0.100, error=4.996
# >epoch=129, lrate=0.100, error=4.996
# >epoch=130, lrate=0.100, error=4.996
# >epoch=131, lrate=0.100, error=4.996
# >epoch=132, lrate=0.100, error=4.996
# >epoch=133, lrate=0.100, error=4.996
# >epoch=134, lrate=0.100, error=4.996
# >epoch=135, lrate=0.100, error=4.996
# >epoch=136, lrate=0.100, error=4.996
# >epoch=137, lrate=0.100, error=4.996
# >epoch=138, lrate=0.100, error=4.996
# >epoch=139, lrate=0.100, error=4.996
# >epoch=140, lrate=0.100, error=4.996
# >epoch=141, lrate=0.100, error=4.996
# >epoch=142, lrate=0.100, error=4.996
# >epoch=143, lrate=0.100, error=4.996
# >epoch=144, lrate=0.100, error=4.996
# >epoch=145, lrate=0.100, error=4.996
# >epoch=146, lrate=0.100, error=4.996
# >epoch=147, lrate=0.100, error=4.996
# >epoch=148, lrate=0.100, error=4.996
# >epoch=149, lrate=0.100, error=4.996
# >epoch=150, lrate=0.100, error=4.996
# >epoch=151, lrate=0.100, error=4.996
# >epoch=152, lrate=0.100, error=4.996
# >epoch=153, lrate=0.100, error=4.996
# >epoch=154, lrate=0.100, error=4.996
# >epoch=155, lrate=0.100, error=4.996
# >epoch=156, lrate=0.100, error=4.996
# >epoch=157, lrate=0.100, error=4.996
# >epoch=158, lrate=0.100, error=4.996
# >epoch=159, lrate=0.100, error=4.996
# >epoch=160, lrate=0.100, error=4.996
# >epoch=161, lrate=0.100, error=4.996
# >epoch=162, lrate=0.100, error=4.996
# >epoch=163, lrate=0.100, error=4.996
# >epoch=164, lrate=0.100, error=4.996
# >epoch=165, lrate=0.100, error=4.996
# >epoch=166, lrate=0.100, error=4.996
# >epoch=167, lrate=0.100, error=4.996
# >epoch=168, lrate=0.100, error=4.996
# >epoch=169, lrate=0.100, error=4.996
# >epoch=170, lrate=0.100, error=4.996
# >epoch=171, lrate=0.100, error=4.996
# >epoch=172, lrate=0.100, error=4.996
# >epoch=173, lrate=0.100, error=4.996
# >epoch=174, lrate=0.100, error=4.996
# >epoch=175, lrate=0.100, error=4.996
# >epoch=176, lrate=0.100, error=4.996
# >epoch=177, lrate=0.100, error=4.996
# >epoch=178, lrate=0.100, error=4.996
# >epoch=179, lrate=0.100, error=4.996
# >epoch=180, lrate=0.100, error=4.996
# >epoch=181, lrate=0.100, error=4.996
# >epoch=182, lrate=0.100, error=4.996
# >epoch=183, lrate=0.100, error=4.996
# >epoch=184, lrate=0.100, error=4.996
# >epoch=185, lrate=0.100, error=4.996
# >epoch=186, lrate=0.100, error=4.996
# >epoch=187, lrate=0.100, error=4.996
# >epoch=188, lrate=0.100, error=4.996
# >epoch=189, lrate=0.100, error=4.996
# >epoch=190, lrate=0.100, error=4.996
# >epoch=191, lrate=0.100, error=4.996
# >epoch=192, lrate=0.100, error=4.996
# >epoch=193, lrate=0.100, error=4.996
# >epoch=194, lrate=0.100, error=4.996
# >epoch=195, lrate=0.100, error=4.996
# >epoch=196, lrate=0.100, error=4.996
# >epoch=197, lrate=0.100, error=4.996
# >epoch=198, lrate=0.100, error=4.996
# >epoch=199, lrate=0.100, error=4.996
# >epoch=200, lrate=0.100, error=4.996
# >epoch=201, lrate=0.100, error=4.996
# >epoch=202, lrate=0.100, error=4.996
# >epoch=203, lrate=0.100, error=4.996
# >epoch=204, lrate=0.100, error=4.996
# >epoch=205, lrate=0.100, error=4.996
# >epoch=206, lrate=0.100, error=4.996
# >epoch=207, lrate=0.100, error=4.996
# >epoch=208, lrate=0.100, error=4.996
# >epoch=209, lrate=0.100, error=4.996
# >epoch=210, lrate=0.100, error=4.996
# >epoch=211, lrate=0.100, error=4.996
# >epoch=212, lrate=0.100, error=4.996
# >epoch=213, lrate=0.100, error=4.996
# >epoch=214, lrate=0.100, error=4.996
# >epoch=215, lrate=0.100, error=4.996
# >epoch=216, lrate=0.100, error=4.996
# >epoch=217, lrate=0.100, error=4.996
# >epoch=218, lrate=0.100, error=4.996
# >epoch=219, lrate=0.100, error=4.996
# >epoch=220, lrate=0.100, error=4.996
# >epoch=221, lrate=0.100, error=4.996
# >epoch=222, lrate=0.100, error=4.996
# >epoch=223, lrate=0.100, error=4.996
# >epoch=224, lrate=0.100, error=4.996
# >epoch=225, lrate=0.100, error=4.996
# >epoch=226, lrate=0.100, error=4.996
# >epoch=227, lrate=0.100, error=4.996
# >epoch=228, lrate=0.100, error=4.996
# >epoch=229, lrate=0.100, error=4.996
# >epoch=230, lrate=0.100, error=4.996
# >epoch=231, lrate=0.100, error=4.996
# >epoch=232, lrate=0.100, error=4.996
# >epoch=233, lrate=0.100, error=4.996
# >epoch=234, lrate=0.100, error=4.996
# >epoch=235, lrate=0.100, error=4.996
# >epoch=236, lrate=0.100, error=4.996
# >epoch=237, lrate=0.100, error=4.996
# >epoch=238, lrate=0.100, error=4.996
# >epoch=239, lrate=0.100, error=4.996
# >epoch=240, lrate=0.100, error=4.996
# >epoch=241, lrate=0.100, error=4.996
# >epoch=242, lrate=0.100, error=4.996
# >epoch=243, lrate=0.100, error=4.996
# >epoch=244, lrate=0.100, error=4.996
# >epoch=245, lrate=0.100, error=4.996
# >epoch=246, lrate=0.100, error=4.996
# >epoch=247, lrate=0.100, error=4.996
# >epoch=248, lrate=0.100, error=4.996
# >epoch=249, lrate=0.100, error=4.996
# >epoch=250, lrate=0.100, error=4.996
# >epoch=251, lrate=0.100, error=4.996
# >epoch=252, lrate=0.100, error=4.996
# >epoch=253, lrate=0.100, error=4.996
# >epoch=254, lrate=0.100, error=4.996
# >epoch=255, lrate=0.100, error=4.996
# >epoch=256, lrate=0.100, error=4.996
# >epoch=257, lrate=0.100, error=4.996
# >epoch=258, lrate=0.100, error=4.996
# >epoch=259, lrate=0.100, error=4.996
# >epoch=260, lrate=0.100, error=4.996
# >epoch=261, lrate=0.100, error=4.996
# >epoch=262, lrate=0.100, error=4.996
# >epoch=263, lrate=0.100, error=4.996
# >epoch=264, lrate=0.100, error=4.996
# >epoch=265, lrate=0.100, error=4.996
# >epoch=266, lrate=0.100, error=4.996
# >epoch=267, lrate=0.100, error=4.996
# >epoch=268, lrate=0.100, error=4.996
# >epoch=269, lrate=0.100, error=4.996
# >epoch=270, lrate=0.100, error=4.996
# >epoch=271, lrate=0.100, error=4.996
# >epoch=272, lrate=0.100, error=4.996
# >epoch=273, lrate=0.100, error=4.996
# >epoch=274, lrate=0.100, error=4.996
# >epoch=275, lrate=0.100, error=4.996
# >epoch=276, lrate=0.100, error=4.996
# >epoch=277, lrate=0.100, error=4.996
# >epoch=278, lrate=0.100, error=4.996
# >epoch=279, lrate=0.100, error=4.996
# >epoch=280, lrate=0.100, error=4.996
# >epoch=281, lrate=0.100, error=4.996
# >epoch=282, lrate=0.100, error=4.996
# >epoch=283, lrate=0.100, error=4.996
# >epoch=284, lrate=0.100, error=4.996
# >epoch=285, lrate=0.100, error=4.996
# >epoch=286, lrate=0.100, error=4.996
# >epoch=287, lrate=0.100, error=4.996
# >epoch=288, lrate=0.100, error=4.996
# >epoch=289, lrate=0.100, error=4.996
# >epoch=290, lrate=0.100, error=4.996
# >epoch=291, lrate=0.100, error=4.996
# >epoch=292, lrate=0.100, error=4.996
# >epoch=293, lrate=0.100, error=4.996
# >epoch=294, lrate=0.100, error=4.996
# >epoch=295, lrate=0.100, error=4.996
# >epoch=296, lrate=0.100, error=4.996
# >epoch=297, lrate=0.100, error=4.996
# >epoch=298, lrate=0.100, error=4.996
# >epoch=299, lrate=0.100, error=4.996
# >epoch=300, lrate=0.100, error=4.996
# >epoch=301, lrate=0.100, error=4.996
# >epoch=302, lrate=0.100, error=4.996
# >epoch=303, lrate=0.100, error=4.996
# >epoch=304, lrate=0.100, error=4.996
# >epoch=305, lrate=0.100, error=4.996
# >epoch=306, lrate=0.100, error=4.996
# >epoch=307, lrate=0.100, error=4.996
# >epoch=308, lrate=0.100, error=4.996
# >epoch=309, lrate=0.100, error=4.996
# >epoch=310, lrate=0.100, error=4.997
# >epoch=311, lrate=0.100, error=4.997
# >epoch=312, lrate=0.100, error=4.997
# >epoch=313, lrate=0.100, error=4.997
# >epoch=314, lrate=0.100, error=4.997
# >epoch=315, lrate=0.100, error=4.997
# >epoch=316, lrate=0.100, error=4.997
# >epoch=317, lrate=0.100, error=4.997
# >epoch=318, lrate=0.100, error=4.997
# >epoch=319, lrate=0.100, error=4.997
# >epoch=320, lrate=0.100, error=4.997
# >epoch=321, lrate=0.100, error=4.997
# >epoch=322, lrate=0.100, error=4.997
# >epoch=323, lrate=0.100, error=4.997
# >epoch=324, lrate=0.100, error=4.997
# >epoch=325, lrate=0.100, error=4.997
# >epoch=326, lrate=0.100, error=4.997
# >epoch=327, lrate=0.100, error=4.997
# >epoch=328, lrate=0.100, error=4.997
# >epoch=329, lrate=0.100, error=4.997
# >epoch=330, lrate=0.100, error=4.997
# >epoch=331, lrate=0.100, error=4.997
# >epoch=332, lrate=0.100, error=4.997
# >epoch=333, lrate=0.100, error=4.997
# >epoch=334, lrate=0.100, error=4.997
# >epoch=335, lrate=0.100, error=4.997
# >epoch=336, lrate=0.100, error=4.997
# >epoch=337, lrate=0.100, error=4.997
# >epoch=338, lrate=0.100, error=4.997
# >epoch=339, lrate=0.100, error=4.997
# >epoch=340, lrate=0.100, error=4.997
# >epoch=341, lrate=0.100, error=4.997
# >epoch=342, lrate=0.100, error=4.997
# >epoch=343, lrate=0.100, error=4.997
# >epoch=344, lrate=0.100, error=4.997
# >epoch=345, lrate=0.100, error=4.997
# >epoch=346, lrate=0.100, error=4.997
# >epoch=347, lrate=0.100, error=4.997
# >epoch=348, lrate=0.100, error=4.997
# >epoch=349, lrate=0.100, error=4.997
# >epoch=350, lrate=0.100, error=4.997
# >epoch=351, lrate=0.100, error=4.997
# >epoch=352, lrate=0.100, error=4.997
# >epoch=353, lrate=0.100, error=4.997
# >epoch=354, lrate=0.100, error=4.997
# >epoch=355, lrate=0.100, error=4.997
# >epoch=356, lrate=0.100, error=4.997
# >epoch=357, lrate=0.100, error=4.997
# >epoch=358, lrate=0.100, error=4.997
# >epoch=359, lrate=0.100, error=4.997
# >epoch=360, lrate=0.100, error=4.997
# >epoch=361, lrate=0.100, error=4.997
# >epoch=362, lrate=0.100, error=4.997
# >epoch=363, lrate=0.100, error=4.997
# >epoch=364, lrate=0.100, error=4.997
# >epoch=365, lrate=0.100, error=4.997
# >epoch=366, lrate=0.100, error=4.997
# >epoch=367, lrate=0.100, error=4.997
# >epoch=368, lrate=0.100, error=4.997
# >epoch=369, lrate=0.100, error=4.997
# >epoch=370, lrate=0.100, error=4.997
# >epoch=371, lrate=0.100, error=4.997
# >epoch=372, lrate=0.100, error=4.997
# >epoch=373, lrate=0.100, error=4.997
# >epoch=374, lrate=0.100, error=4.997
# >epoch=375, lrate=0.100, error=4.997
# >epoch=376, lrate=0.100, error=4.997
# >epoch=377, lrate=0.100, error=4.997
# >epoch=378, lrate=0.100, error=4.997
# >epoch=379, lrate=0.100, error=4.997
# >epoch=380, lrate=0.100, error=4.997
# >epoch=381, lrate=0.100, error=4.997
# >epoch=382, lrate=0.100, error=4.997
# >epoch=383, lrate=0.100, error=4.997
# >epoch=384, lrate=0.100, error=4.997
# >epoch=385, lrate=0.100, error=4.997
# >epoch=386, lrate=0.100, error=4.997
# >epoch=387, lrate=0.100, error=4.997
# >epoch=388, lrate=0.100, error=4.997
# >epoch=389, lrate=0.100, error=4.997
# >epoch=390, lrate=0.100, error=4.997
# >epoch=391, lrate=0.100, error=4.997
# >epoch=392, lrate=0.100, error=4.997
# >epoch=393, lrate=0.100, error=4.997
# >epoch=394, lrate=0.100, error=4.997
# >epoch=395, lrate=0.100, error=4.997
# >epoch=396, lrate=0.100, error=4.997
# >epoch=397, lrate=0.100, error=4.997
# >epoch=398, lrate=0.100, error=4.997
# >epoch=399, lrate=0.100, error=4.997
# >epoch=400, lrate=0.100, error=4.997
# >epoch=401, lrate=0.100, error=4.997
# >epoch=402, lrate=0.100, error=4.997
# >epoch=403, lrate=0.100, error=4.997
# >epoch=404, lrate=0.100, error=4.997
# >epoch=405, lrate=0.100, error=4.997
# >epoch=406, lrate=0.100, error=4.997
# >epoch=407, lrate=0.100, error=4.997
# >epoch=408, lrate=0.100, error=4.997
# >epoch=409, lrate=0.100, error=4.997
# >epoch=410, lrate=0.100, error=4.997
# >epoch=411, lrate=0.100, error=4.997
# >epoch=412, lrate=0.100, error=4.997
# >epoch=413, lrate=0.100, error=4.997
# >epoch=414, lrate=0.100, error=4.997
# >epoch=415, lrate=0.100, error=4.997
# >epoch=416, lrate=0.100, error=4.998
# >epoch=417, lrate=0.100, error=4.998
# >epoch=418, lrate=0.100, error=4.998
# >epoch=419, lrate=0.100, error=4.998
# >epoch=420, lrate=0.100, error=4.998
# >epoch=421, lrate=0.100, error=4.998
# >epoch=422, lrate=0.100, error=4.998
# >epoch=423, lrate=0.100, error=4.998
# >epoch=424, lrate=0.100, error=4.998
# >epoch=425, lrate=0.100, error=4.998
# >epoch=426, lrate=0.100, error=4.998
# >epoch=427, lrate=0.100, error=4.998
# >epoch=428, lrate=0.100, error=4.998
# >epoch=429, lrate=0.100, error=4.998
# >epoch=430, lrate=0.100, error=4.998
# >epoch=431, lrate=0.100, error=4.998
# >epoch=432, lrate=0.100, error=4.998
# >epoch=433, lrate=0.100, error=4.998
# >epoch=434, lrate=0.100, error=4.998
# >epoch=435, lrate=0.100, error=4.998
# >epoch=436, lrate=0.100, error=4.998
# >epoch=437, lrate=0.100, error=4.998
# >epoch=438, lrate=0.100, error=4.998
# >epoch=439, lrate=0.100, error=4.998
# >epoch=440, lrate=0.100, error=4.998
# >epoch=441, lrate=0.100, error=4.998
# >epoch=442, lrate=0.100, error=4.998
# >epoch=443, lrate=0.100, error=4.998
# >epoch=444, lrate=0.100, error=4.998
# >epoch=445, lrate=0.100, error=4.998
# >epoch=446, lrate=0.100, error=4.999
# >epoch=447, lrate=0.100, error=4.999
# >epoch=448, lrate=0.100, error=4.999
# >epoch=449, lrate=0.100, error=4.999
# >epoch=450, lrate=0.100, error=4.999
# >epoch=451, lrate=0.100, error=4.999
# >epoch=452, lrate=0.100, error=4.999
# >epoch=453, lrate=0.100, error=4.999
# >epoch=454, lrate=0.100, error=4.999
# >epoch=455, lrate=0.100, error=4.999
# >epoch=456, lrate=0.100, error=4.999
# >epoch=457, lrate=0.100, error=4.999
# >epoch=458, lrate=0.100, error=4.999
# >epoch=459, lrate=0.100, error=4.999
# >epoch=460, lrate=0.100, error=5.000
# >epoch=461, lrate=0.100, error=5.000
# >epoch=462, lrate=0.100, error=5.000
# >epoch=463, lrate=0.100, error=5.000
# >epoch=464, lrate=0.100, error=5.000
# >epoch=465, lrate=0.100, error=5.000
# >epoch=466, lrate=0.100, error=5.000
# >epoch=467, lrate=0.100, error=5.000
# >epoch=468, lrate=0.100, error=5.000
# >epoch=469, lrate=0.100, error=5.000
# >epoch=470, lrate=0.100, error=5.001
# >epoch=471, lrate=0.100, error=5.001
# >epoch=472, lrate=0.100, error=5.001
# >epoch=473, lrate=0.100, error=5.001
# >epoch=474, lrate=0.100, error=5.001
# >epoch=475, lrate=0.100, error=5.001
# >epoch=476, lrate=0.100, error=5.002
# >epoch=477, lrate=0.100, error=5.002
# >epoch=478, lrate=0.100, error=5.002
# >epoch=479, lrate=0.100, error=5.002
# >epoch=480, lrate=0.100, error=5.002
# >epoch=481, lrate=0.100, error=5.003
# >epoch=482, lrate=0.100, error=5.003
# >epoch=483, lrate=0.100, error=5.003
# >epoch=484, lrate=0.100, error=5.003
# >epoch=485, lrate=0.100, error=5.004
# >epoch=486, lrate=0.100, error=5.004
# >epoch=487, lrate=0.100, error=5.004
# >epoch=488, lrate=0.100, error=5.005
# >epoch=489, lrate=0.100, error=5.005
# >epoch=490, lrate=0.100, error=5.006
# >epoch=491, lrate=0.100, error=5.006
# >epoch=492, lrate=0.100, error=5.006
# >epoch=493, lrate=0.100, error=5.007
# >epoch=494, lrate=0.100, error=5.007
# >epoch=495, lrate=0.100, error=5.008
# >epoch=496, lrate=0.100, error=5.009
# >epoch=497, lrate=0.100, error=5.009
# >epoch=498, lrate=0.100, error=5.010
# >epoch=499, lrate=0.100, error=5.011
# >epoch=500, lrate=0.100, error=5.012
# >epoch=501, lrate=0.100, error=5.013
# >epoch=502, lrate=0.100, error=5.014
# >epoch=503, lrate=0.100, error=5.015
# >epoch=504, lrate=0.100, error=5.016
# >epoch=505, lrate=0.100, error=5.018
# >epoch=506, lrate=0.100, error=5.019
# >epoch=507, lrate=0.100, error=5.021
# >epoch=508, lrate=0.100, error=5.023
# >epoch=509, lrate=0.100, error=5.025
# >epoch=510, lrate=0.100, error=5.027
# >epoch=511, lrate=0.100, error=5.029
# >epoch=512, lrate=0.100, error=5.032
# >epoch=513, lrate=0.100, error=5.035
# >epoch=514, lrate=0.100, error=5.038
# >epoch=515, lrate=0.100, error=5.042
# >epoch=516, lrate=0.100, error=5.045
# >epoch=517, lrate=0.100, error=5.049
# >epoch=518, lrate=0.100, error=5.054
# >epoch=519, lrate=0.100, error=5.058
# >epoch=520, lrate=0.100, error=5.063
# >epoch=521, lrate=0.100, error=5.067
# >epoch=522, lrate=0.100, error=5.072
# >epoch=523, lrate=0.100, error=5.076
# >epoch=524, lrate=0.100, error=5.079
# >epoch=525, lrate=0.100, error=5.082
# >epoch=526, lrate=0.100, error=5.083
# >epoch=527, lrate=0.100, error=5.084
# >epoch=528, lrate=0.100, error=5.083
# >epoch=529, lrate=0.100, error=5.081
# >epoch=530, lrate=0.100, error=5.077
# >epoch=531, lrate=0.100, error=5.073
# >epoch=532, lrate=0.100, error=5.067
# >epoch=533, lrate=0.100, error=5.060
# >epoch=534, lrate=0.100, error=5.053
# >epoch=535, lrate=0.100, error=5.044
# >epoch=536, lrate=0.100, error=5.035
# >epoch=537, lrate=0.100, error=5.026
# >epoch=538, lrate=0.100, error=5.015
# >epoch=539, lrate=0.100, error=5.005
# >epoch=540, lrate=0.100, error=4.993
# >epoch=541, lrate=0.100, error=4.981
# >epoch=542, lrate=0.100, error=4.969
# >epoch=543, lrate=0.100, error=4.956
# >epoch=544, lrate=0.100, error=4.943
# >epoch=545, lrate=0.100, error=4.929
# >epoch=546, lrate=0.100, error=4.915
# >epoch=547, lrate=0.100, error=4.900
# >epoch=548, lrate=0.100, error=4.885
# >epoch=549, lrate=0.100, error=4.869
# >epoch=550, lrate=0.100, error=4.853
# >epoch=551, lrate=0.100, error=4.836
# >epoch=552, lrate=0.100, error=4.819
# >epoch=553, lrate=0.100, error=4.801
# >epoch=554, lrate=0.100, error=4.783
# >epoch=555, lrate=0.100, error=4.765
# >epoch=556, lrate=0.100, error=4.746
# >epoch=557, lrate=0.100, error=4.727
# >epoch=558, lrate=0.100, error=4.708
# >epoch=559, lrate=0.100, error=4.688
# >epoch=560, lrate=0.100, error=4.668
# >epoch=561, lrate=0.100, error=4.648
# >epoch=562, lrate=0.100, error=4.627
# >epoch=563, lrate=0.100, error=4.606
# >epoch=564, lrate=0.100, error=4.585
# >epoch=565, lrate=0.100, error=4.564
# >epoch=566, lrate=0.100, error=4.542
# >epoch=567, lrate=0.100, error=4.521
# >epoch=568, lrate=0.100, error=4.499
# >epoch=569, lrate=0.100, error=4.477
# >epoch=570, lrate=0.100, error=4.455
# >epoch=571, lrate=0.100, error=4.433
# >epoch=572, lrate=0.100, error=4.411
# >epoch=573, lrate=0.100, error=4.389
# >epoch=574, lrate=0.100, error=4.367
# >epoch=575, lrate=0.100, error=4.345
# >epoch=576, lrate=0.100, error=4.323
# >epoch=577, lrate=0.100, error=4.301
# >epoch=578, lrate=0.100, error=4.279
# >epoch=579, lrate=0.100, error=4.257
# >epoch=580, lrate=0.100, error=4.235
# >epoch=581, lrate=0.100, error=4.213
# >epoch=582, lrate=0.100, error=4.191
# >epoch=583, lrate=0.100, error=4.169
# >epoch=584, lrate=0.100, error=4.148
# >epoch=585, lrate=0.100, error=4.126
# >epoch=586, lrate=0.100, error=4.105
# >epoch=587, lrate=0.100, error=4.083
# >epoch=588, lrate=0.100, error=4.062
# >epoch=589, lrate=0.100, error=4.041
# >epoch=590, lrate=0.100, error=4.020
# >epoch=591, lrate=0.100, error=4.000
# >epoch=592, lrate=0.100, error=3.979
# >epoch=593, lrate=0.100, error=3.959
# >epoch=594, lrate=0.100, error=3.938
# >epoch=595, lrate=0.100, error=3.918
# >epoch=596, lrate=0.100, error=3.898
# >epoch=597, lrate=0.100, error=3.878
# >epoch=598, lrate=0.100, error=3.858
# >epoch=599, lrate=0.100, error=3.839
# >epoch=600, lrate=0.100, error=3.820
# >epoch=601, lrate=0.100, error=3.800
# >epoch=602, lrate=0.100, error=3.781
# >epoch=603, lrate=0.100, error=3.762
# >epoch=604, lrate=0.100, error=3.744
# >epoch=605, lrate=0.100, error=3.725
# >epoch=606, lrate=0.100, error=3.707
# >epoch=607, lrate=0.100, error=3.689
# >epoch=608, lrate=0.100, error=3.671
# >epoch=609, lrate=0.100, error=3.653
# >epoch=610, lrate=0.100, error=3.635
# >epoch=611, lrate=0.100, error=3.618
# >epoch=612, lrate=0.100, error=3.600
# >epoch=613, lrate=0.100, error=3.583
# >epoch=614, lrate=0.100, error=3.566
# >epoch=615, lrate=0.100, error=3.549
# >epoch=616, lrate=0.100, error=3.533
# >epoch=617, lrate=0.100, error=3.516
# >epoch=618, lrate=0.100, error=3.500
# >epoch=619, lrate=0.100, error=3.483
# >epoch=620, lrate=0.100, error=3.467
# >epoch=621, lrate=0.100, error=3.451
# >epoch=622, lrate=0.100, error=3.436
# >epoch=623, lrate=0.100, error=3.420
# >epoch=624, lrate=0.100, error=3.405
# >epoch=625, lrate=0.100, error=3.389
# >epoch=626, lrate=0.100, error=3.374
# >epoch=627, lrate=0.100, error=3.359
# >epoch=628, lrate=0.100, error=3.345
# >epoch=629, lrate=0.100, error=3.330
# >epoch=630, lrate=0.100, error=3.315
# >epoch=631, lrate=0.100, error=3.301
# >epoch=632, lrate=0.100, error=3.287
# >epoch=633, lrate=0.100, error=3.273
# >epoch=634, lrate=0.100, error=3.259
# >epoch=635, lrate=0.100, error=3.245
# >epoch=636, lrate=0.100, error=3.231
# >epoch=637, lrate=0.100, error=3.218
# >epoch=638, lrate=0.100, error=3.204
# >epoch=639, lrate=0.100, error=3.191
# >epoch=640, lrate=0.100, error=3.178
# >epoch=641, lrate=0.100, error=3.165
# >epoch=642, lrate=0.100, error=3.152
# >epoch=643, lrate=0.100, error=3.139
# >epoch=644, lrate=0.100, error=3.126
# >epoch=645, lrate=0.100, error=3.114
# >epoch=646, lrate=0.100, error=3.101
# >epoch=647, lrate=0.100, error=3.089
# >epoch=648, lrate=0.100, error=3.077
# >epoch=649, lrate=0.100, error=3.065
# >epoch=650, lrate=0.100, error=3.053
# >epoch=651, lrate=0.100, error=3.041
# >epoch=652, lrate=0.100, error=3.029
# >epoch=653, lrate=0.100, error=3.018
# >epoch=654, lrate=0.100, error=3.006
# >epoch=655, lrate=0.100, error=2.995
# >epoch=656, lrate=0.100, error=2.984
# >epoch=657, lrate=0.100, error=2.972
# >epoch=658, lrate=0.100, error=2.961
# >epoch=659, lrate=0.100, error=2.950
# >epoch=660, lrate=0.100, error=2.939
# >epoch=661, lrate=0.100, error=2.929
# >epoch=662, lrate=0.100, error=2.918
# >epoch=663, lrate=0.100, error=2.907
# >epoch=664, lrate=0.100, error=2.897
# >epoch=665, lrate=0.100, error=2.887
# >epoch=666, lrate=0.100, error=2.876
# >epoch=667, lrate=0.100, error=2.866
# >epoch=668, lrate=0.100, error=2.856
# >epoch=669, lrate=0.100, error=2.846
# >epoch=670, lrate=0.100, error=2.836
# >epoch=671, lrate=0.100, error=2.826
# >epoch=672, lrate=0.100, error=2.816
# >epoch=673, lrate=0.100, error=2.807
# >epoch=674, lrate=0.100, error=2.797
# >epoch=675, lrate=0.100, error=2.788
# >epoch=676, lrate=0.100, error=2.778
# >epoch=677, lrate=0.100, error=2.769
# >epoch=678, lrate=0.100, error=2.760
# >epoch=679, lrate=0.100, error=2.751
# >epoch=680, lrate=0.100, error=2.741
# >epoch=681, lrate=0.100, error=2.732
# >epoch=682, lrate=0.100, error=2.723
# >epoch=683, lrate=0.100, error=2.715
# >epoch=684, lrate=0.100, error=2.706
# >epoch=685, lrate=0.100, error=2.697
# >epoch=686, lrate=0.100, error=2.688
# >epoch=687, lrate=0.100, error=2.680
# >epoch=688, lrate=0.100, error=2.671
# >epoch=689, lrate=0.100, error=2.663
# >epoch=690, lrate=0.100, error=2.655
# >epoch=691, lrate=0.100, error=2.646
# >epoch=692, lrate=0.100, error=2.638
# >epoch=693, lrate=0.100, error=2.630
# >epoch=694, lrate=0.100, error=2.622
# >epoch=695, lrate=0.100, error=2.614
# >epoch=696, lrate=0.100, error=2.606
# >epoch=697, lrate=0.100, error=2.598
# >epoch=698, lrate=0.100, error=2.590
# >epoch=699, lrate=0.100, error=2.582
# >epoch=700, lrate=0.100, error=2.575
# >epoch=701, lrate=0.100, error=2.567
# >epoch=702, lrate=0.100, error=2.559
# >epoch=703, lrate=0.100, error=2.552
# >epoch=704, lrate=0.100, error=2.544
# >epoch=705, lrate=0.100, error=2.537
# >epoch=706, lrate=0.100, error=2.530
# >epoch=707, lrate=0.100, error=2.522
# >epoch=708, lrate=0.100, error=2.515
# >epoch=709, lrate=0.100, error=2.508
# >epoch=710, lrate=0.100, error=2.501
# >epoch=711, lrate=0.100, error=2.494
# >epoch=712, lrate=0.100, error=2.487
# >epoch=713, lrate=0.100, error=2.480
# >epoch=714, lrate=0.100, error=2.473
# >epoch=715, lrate=0.100, error=2.466
# >epoch=716, lrate=0.100, error=2.459
# >epoch=717, lrate=0.100, error=2.452
# >epoch=718, lrate=0.100, error=2.446
# >epoch=719, lrate=0.100, error=2.439
# >epoch=720, lrate=0.100, error=2.432
# >epoch=721, lrate=0.100, error=2.426
# >epoch=722, lrate=0.100, error=2.419
# >epoch=723, lrate=0.100, error=2.413
# >epoch=724, lrate=0.100, error=2.406
# >epoch=725, lrate=0.100, error=2.400
# >epoch=726, lrate=0.100, error=2.394
# >epoch=727, lrate=0.100, error=2.387
# >epoch=728, lrate=0.100, error=2.381
# >epoch=729, lrate=0.100, error=2.375
# >epoch=730, lrate=0.100, error=2.369
# >epoch=731, lrate=0.100, error=2.362
# >epoch=732, lrate=0.100, error=2.356
# >epoch=733, lrate=0.100, error=2.350
# >epoch=734, lrate=0.100, error=2.344
# >epoch=735, lrate=0.100, error=2.338
# >epoch=736, lrate=0.100, error=2.333
# >epoch=737, lrate=0.100, error=2.327
# >epoch=738, lrate=0.100, error=2.321
# >epoch=739, lrate=0.100, error=2.315
# >epoch=740, lrate=0.100, error=2.309
# >epoch=741, lrate=0.100, error=2.304
# >epoch=742, lrate=0.100, error=2.298
# >epoch=743, lrate=0.100, error=2.292
# >epoch=744, lrate=0.100, error=2.287
# >epoch=745, lrate=0.100, error=2.281
# >epoch=746, lrate=0.100, error=2.276
# >epoch=747, lrate=0.100, error=2.270
# >epoch=748, lrate=0.100, error=2.265
# >epoch=749, lrate=0.100, error=2.259
# >epoch=750, lrate=0.100, error=2.254
# >epoch=751, lrate=0.100, error=2.249
# >epoch=752, lrate=0.100, error=2.243
# >epoch=753, lrate=0.100, error=2.238
# >epoch=754, lrate=0.100, error=2.233
# >epoch=755, lrate=0.100, error=2.227
# >epoch=756, lrate=0.100, error=2.222
# >epoch=757, lrate=0.100, error=2.217
# >epoch=758, lrate=0.100, error=2.212
# >epoch=759, lrate=0.100, error=2.207
# >epoch=760, lrate=0.100, error=2.202
# >epoch=761, lrate=0.100, error=2.197
# >epoch=762, lrate=0.100, error=2.192
# >epoch=763, lrate=0.100, error=2.187
# >epoch=764, lrate=0.100, error=2.182
# >epoch=765, lrate=0.100, error=2.177
# >epoch=766, lrate=0.100, error=2.172
# >epoch=767, lrate=0.100, error=2.167
# >epoch=768, lrate=0.100, error=2.163
# >epoch=769, lrate=0.100, error=2.158
# >epoch=770, lrate=0.100, error=2.153
# >epoch=771, lrate=0.100, error=2.148
# >epoch=772, lrate=0.100, error=2.144
# >epoch=773, lrate=0.100, error=2.139
# >epoch=774, lrate=0.100, error=2.134
# >epoch=775, lrate=0.100, error=2.130
# >epoch=776, lrate=0.100, error=2.125
# >epoch=777, lrate=0.100, error=2.121
# >epoch=778, lrate=0.100, error=2.116
# >epoch=779, lrate=0.100, error=2.112
# >epoch=780, lrate=0.100, error=2.107
# >epoch=781, lrate=0.100, error=2.103
# >epoch=782, lrate=0.100, error=2.098
# >epoch=783, lrate=0.100, error=2.094
# >epoch=784, lrate=0.100, error=2.090
# >epoch=785, lrate=0.100, error=2.085
# >epoch=786, lrate=0.100, error=2.081
# >epoch=787, lrate=0.100, error=2.077
# >epoch=788, lrate=0.100, error=2.072
# >epoch=789, lrate=0.100, error=2.068
# >epoch=790, lrate=0.100, error=2.064
# >epoch=791, lrate=0.100, error=2.060
# >epoch=792, lrate=0.100, error=2.056
# >epoch=793, lrate=0.100, error=2.051
# >epoch=794, lrate=0.100, error=2.047
# >epoch=795, lrate=0.100, error=2.043
# >epoch=796, lrate=0.100, error=2.039
# >epoch=797, lrate=0.100, error=2.035
# >epoch=798, lrate=0.100, error=2.031
# >epoch=799, lrate=0.100, error=2.027
# >epoch=800, lrate=0.100, error=2.023
# >epoch=801, lrate=0.100, error=2.019
# >epoch=802, lrate=0.100, error=2.015
# >epoch=803, lrate=0.100, error=2.011
# >epoch=804, lrate=0.100, error=2.007
# >epoch=805, lrate=0.100, error=2.003
# >epoch=806, lrate=0.100, error=2.000
# >epoch=807, lrate=0.100, error=1.996
# >epoch=808, lrate=0.100, error=1.992
# >epoch=809, lrate=0.100, error=1.988
# >epoch=810, lrate=0.100, error=1.984
# >epoch=811, lrate=0.100, error=1.981
# >epoch=812, lrate=0.100, error=1.977
# >epoch=813, lrate=0.100, error=1.973
# >epoch=814, lrate=0.100, error=1.969
# >epoch=815, lrate=0.100, error=1.966
# >epoch=816, lrate=0.100, error=1.962
# >epoch=817, lrate=0.100, error=1.959
# >epoch=818, lrate=0.100, error=1.955
# >epoch=819, lrate=0.100, error=1.951
# >epoch=820, lrate=0.100, error=1.948
# >epoch=821, lrate=0.100, error=1.944
# >epoch=822, lrate=0.100, error=1.941
# >epoch=823, lrate=0.100, error=1.937
# >epoch=824, lrate=0.100, error=1.934
# >epoch=825, lrate=0.100, error=1.930
# >epoch=826, lrate=0.100, error=1.927
# >epoch=827, lrate=0.100, error=1.923
# >epoch=828, lrate=0.100, error=1.920
# >epoch=829, lrate=0.100, error=1.916
# >epoch=830, lrate=0.100, error=1.913
# >epoch=831, lrate=0.100, error=1.909
# >epoch=832, lrate=0.100, error=1.906
# >epoch=833, lrate=0.100, error=1.903
# >epoch=834, lrate=0.100, error=1.899
# >epoch=835, lrate=0.100, error=1.896
# >epoch=836, lrate=0.100, error=1.893
# >epoch=837, lrate=0.100, error=1.889
# >epoch=838, lrate=0.100, error=1.886
# >epoch=839, lrate=0.100, error=1.883
# >epoch=840, lrate=0.100, error=1.880
# >epoch=841, lrate=0.100, error=1.876
# >epoch=842, lrate=0.100, error=1.873
# >epoch=843, lrate=0.100, error=1.870
# >epoch=844, lrate=0.100, error=1.867
# >epoch=845, lrate=0.100, error=1.864
# >epoch=846, lrate=0.100, error=1.861
# >epoch=847, lrate=0.100, error=1.857
# >epoch=848, lrate=0.100, error=1.854
# >epoch=849, lrate=0.100, error=1.851
# >epoch=850, lrate=0.100, error=1.848
# >epoch=851, lrate=0.100, error=1.845
# >epoch=852, lrate=0.100, error=1.842
# >epoch=853, lrate=0.100, error=1.839
# >epoch=854, lrate=0.100, error=1.836
# >epoch=855, lrate=0.100, error=1.833
# >epoch=856, lrate=0.100, error=1.830
# >epoch=857, lrate=0.100, error=1.827
# >epoch=858, lrate=0.100, error=1.824
# >epoch=859, lrate=0.100, error=1.821
# >epoch=860, lrate=0.100, error=1.818
# >epoch=861, lrate=0.100, error=1.815
# >epoch=862, lrate=0.100, error=1.812
# >epoch=863, lrate=0.100, error=1.809
# >epoch=864, lrate=0.100, error=1.806
# >epoch=865, lrate=0.100, error=1.803
# >epoch=866, lrate=0.100, error=1.801
# >epoch=867, lrate=0.100, error=1.798
# >epoch=868, lrate=0.100, error=1.795
# >epoch=869, lrate=0.100, error=1.792
# >epoch=870, lrate=0.100, error=1.789
# >epoch=871, lrate=0.100, error=1.786
# >epoch=872, lrate=0.100, error=1.784
# >epoch=873, lrate=0.100, error=1.781
# >epoch=874, lrate=0.100, error=1.778
# >epoch=875, lrate=0.100, error=1.775
# >epoch=876, lrate=0.100, error=1.772
# >epoch=877, lrate=0.100, error=1.770
# >epoch=878, lrate=0.100, error=1.767
# >epoch=879, lrate=0.100, error=1.764
# >epoch=880, lrate=0.100, error=1.762
# >epoch=881, lrate=0.100, error=1.759
# >epoch=882, lrate=0.100, error=1.756
# >epoch=883, lrate=0.100, error=1.754
# >epoch=884, lrate=0.100, error=1.751
# >epoch=885, lrate=0.100, error=1.748
# >epoch=886, lrate=0.100, error=1.746
# >epoch=887, lrate=0.100, error=1.743
# >epoch=888, lrate=0.100, error=1.740
# >epoch=889, lrate=0.100, error=1.738
# >epoch=890, lrate=0.100, error=1.735
# >epoch=891, lrate=0.100, error=1.733
# >epoch=892, lrate=0.100, error=1.730
# >epoch=893, lrate=0.100, error=1.728
# >epoch=894, lrate=0.100, error=1.725
# >epoch=895, lrate=0.100, error=1.722
# >epoch=896, lrate=0.100, error=1.720
# >epoch=897, lrate=0.100, error=1.717
# >epoch=898, lrate=0.100, error=1.715
# >epoch=899, lrate=0.100, error=1.712
# >epoch=900, lrate=0.100, error=1.710
# >epoch=901, lrate=0.100, error=1.708
# >epoch=902, lrate=0.100, error=1.705
# >epoch=903, lrate=0.100, error=1.703
# >epoch=904, lrate=0.100, error=1.700
# >epoch=905, lrate=0.100, error=1.698
# >epoch=906, lrate=0.100, error=1.695
# >epoch=907, lrate=0.100, error=1.693
# >epoch=908, lrate=0.100, error=1.691
# >epoch=909, lrate=0.100, error=1.688
# >epoch=910, lrate=0.100, error=1.686
# >epoch=911, lrate=0.100, error=1.683
# >epoch=912, lrate=0.100, error=1.681
# >epoch=913, lrate=0.100, error=1.679
# >epoch=914, lrate=0.100, error=1.676
# >epoch=915, lrate=0.100, error=1.674
# >epoch=916, lrate=0.100, error=1.672
# >epoch=917, lrate=0.100, error=1.669
# >epoch=918, lrate=0.100, error=1.667
# >epoch=919, lrate=0.100, error=1.665
# >epoch=920, lrate=0.100, error=1.662
# >epoch=921, lrate=0.100, error=1.660
# >epoch=922, lrate=0.100, error=1.658
# >epoch=923, lrate=0.100, error=1.656
# >epoch=924, lrate=0.100, error=1.653
# >epoch=925, lrate=0.100, error=1.651
# >epoch=926, lrate=0.100, error=1.649
# >epoch=927, lrate=0.100, error=1.647
# >epoch=928, lrate=0.100, error=1.644
# >epoch=929, lrate=0.100, error=1.642
# >epoch=930, lrate=0.100, error=1.640
# >epoch=931, lrate=0.100, error=1.638
# >epoch=932, lrate=0.100, error=1.636
# >epoch=933, lrate=0.100, error=1.633
# >epoch=934, lrate=0.100, error=1.631
# >epoch=935, lrate=0.100, error=1.629
# >epoch=936, lrate=0.100, error=1.627
# >epoch=937, lrate=0.100, error=1.625
# >epoch=938, lrate=0.100, error=1.623
# >epoch=939, lrate=0.100, error=1.621
# >epoch=940, lrate=0.100, error=1.618
# >epoch=941, lrate=0.100, error=1.616
# >epoch=942, lrate=0.100, error=1.614
# >epoch=943, lrate=0.100, error=1.612
# >epoch=944, lrate=0.100, error=1.610
# >epoch=945, lrate=0.100, error=1.608
# >epoch=946, lrate=0.100, error=1.606
# >epoch=947, lrate=0.100, error=1.604
# >epoch=948, lrate=0.100, error=1.602
# >epoch=949, lrate=0.100, error=1.600
# >epoch=950, lrate=0.100, error=1.598
# >epoch=951, lrate=0.100, error=1.596
# >epoch=952, lrate=0.100, error=1.594
# >epoch=953, lrate=0.100, error=1.592
# >epoch=954, lrate=0.100, error=1.590
# >epoch=955, lrate=0.100, error=1.588
# >epoch=956, lrate=0.100, error=1.586
# >epoch=957, lrate=0.100, error=1.584
# >epoch=958, lrate=0.100, error=1.582
# >epoch=959, lrate=0.100, error=1.580
# >epoch=960, lrate=0.100, error=1.578
# >epoch=961, lrate=0.100, error=1.576
# >epoch=962, lrate=0.100, error=1.574
# >epoch=963, lrate=0.100, error=1.572
# >epoch=964, lrate=0.100, error=1.570
# >epoch=965, lrate=0.100, error=1.568
# >epoch=966, lrate=0.100, error=1.566
# >epoch=967, lrate=0.100, error=1.564
# >epoch=968, lrate=0.100, error=1.562
# >epoch=969, lrate=0.100, error=1.560
# >epoch=970, lrate=0.100, error=1.558
# >epoch=971, lrate=0.100, error=1.556
# >epoch=972, lrate=0.100, error=1.555
# >epoch=973, lrate=0.100, error=1.553
# >epoch=974, lrate=0.100, error=1.551
# >epoch=975, lrate=0.100, error=1.549
# >epoch=976, lrate=0.100, error=1.547
# >epoch=977, lrate=0.100, error=1.545
# >epoch=978, lrate=0.100, error=1.543
# >epoch=979, lrate=0.100, error=1.542
# >epoch=980, lrate=0.100, error=1.540
# >epoch=981, lrate=0.100, error=1.538
# >epoch=982, lrate=0.100, error=1.536
# >epoch=983, lrate=0.100, error=1.534
# >epoch=984, lrate=0.100, error=1.532
# >epoch=985, lrate=0.100, error=1.531
# >epoch=986, lrate=0.100, error=1.529
# >epoch=987, lrate=0.100, error=1.527
# >epoch=988, lrate=0.100, error=1.525
# >epoch=989, lrate=0.100, error=1.523
# >epoch=990, lrate=0.100, error=1.522
# >epoch=991, lrate=0.100, error=1.520
# >epoch=992, lrate=0.100, error=1.518
# >epoch=993, lrate=0.100, error=1.516
# >epoch=994, lrate=0.100, error=1.515
# >epoch=995, lrate=0.100, error=1.513
# >epoch=996, lrate=0.100, error=1.511
# >epoch=997, lrate=0.100, error=1.509
# >epoch=998, lrate=0.100, error=1.508
# >epoch=999, lrate=0.100, error=1.506
# >epoch=1000, lrate=0.100, error=1.504
# >epoch=1001, lrate=0.100, error=1.503
# >epoch=1002, lrate=0.100, error=1.501
# >epoch=1003, lrate=0.100, error=1.499
# >epoch=1004, lrate=0.100, error=1.497
# >epoch=1005, lrate=0.100, error=1.496
# >epoch=1006, lrate=0.100, error=1.494
# >epoch=1007, lrate=0.100, error=1.492
# >epoch=1008, lrate=0.100, error=1.491
# >epoch=1009, lrate=0.100, error=1.489
# >epoch=1010, lrate=0.100, error=1.487
# >epoch=1011, lrate=0.100, error=1.486
# >epoch=1012, lrate=0.100, error=1.484
# >epoch=1013, lrate=0.100, error=1.482
# >epoch=1014, lrate=0.100, error=1.481
# >epoch=1015, lrate=0.100, error=1.479
# >epoch=1016, lrate=0.100, error=1.477
# >epoch=1017, lrate=0.100, error=1.476
# >epoch=1018, lrate=0.100, error=1.474
# >epoch=1019, lrate=0.100, error=1.473
# >epoch=1020, lrate=0.100, error=1.471
# >epoch=1021, lrate=0.100, error=1.469
# >epoch=1022, lrate=0.100, error=1.468
# >epoch=1023, lrate=0.100, error=1.466
# >epoch=1024, lrate=0.100, error=1.465
# >epoch=1025, lrate=0.100, error=1.463
# >epoch=1026, lrate=0.100, error=1.461
# >epoch=1027, lrate=0.100, error=1.460
# >epoch=1028, lrate=0.100, error=1.458
# >epoch=1029, lrate=0.100, error=1.457
# >epoch=1030, lrate=0.100, error=1.455
# >epoch=1031, lrate=0.100, error=1.454
# >epoch=1032, lrate=0.100, error=1.452
# >epoch=1033, lrate=0.100, error=1.451
# >epoch=1034, lrate=0.100, error=1.449
# >epoch=1035, lrate=0.100, error=1.447
# >epoch=1036, lrate=0.100, error=1.446
# >epoch=1037, lrate=0.100, error=1.444
# >epoch=1038, lrate=0.100, error=1.443
# >epoch=1039, lrate=0.100, error=1.441
# >epoch=1040, lrate=0.100, error=1.440
# >epoch=1041, lrate=0.100, error=1.438
# >epoch=1042, lrate=0.100, error=1.437
# >epoch=1043, lrate=0.100, error=1.435
# >epoch=1044, lrate=0.100, error=1.434
# >epoch=1045, lrate=0.100, error=1.432
# >epoch=1046, lrate=0.100, error=1.431
# >epoch=1047, lrate=0.100, error=1.429
# >epoch=1048, lrate=0.100, error=1.428
# >epoch=1049, lrate=0.100, error=1.426
# >epoch=1050, lrate=0.100, error=1.425
# >epoch=1051, lrate=0.100, error=1.423
# >epoch=1052, lrate=0.100, error=1.422
# >epoch=1053, lrate=0.100, error=1.421
# >epoch=1054, lrate=0.100, error=1.419
# >epoch=1055, lrate=0.100, error=1.418
# >epoch=1056, lrate=0.100, error=1.416
# >epoch=1057, lrate=0.100, error=1.415
# >epoch=1058, lrate=0.100, error=1.413
# >epoch=1059, lrate=0.100, error=1.412
# >epoch=1060, lrate=0.100, error=1.410
# >epoch=1061, lrate=0.100, error=1.409
# >epoch=1062, lrate=0.100, error=1.408
# >epoch=1063, lrate=0.100, error=1.406
# >epoch=1064, lrate=0.100, error=1.405
# >epoch=1065, lrate=0.100, error=1.403
# >epoch=1066, lrate=0.100, error=1.402
# >epoch=1067, lrate=0.100, error=1.401
# >epoch=1068, lrate=0.100, error=1.399
# >epoch=1069, lrate=0.100, error=1.398
# >epoch=1070, lrate=0.100, error=1.396
# >epoch=1071, lrate=0.100, error=1.395
# >epoch=1072, lrate=0.100, error=1.394
# >epoch=1073, lrate=0.100, error=1.392
# >epoch=1074, lrate=0.100, error=1.391
# >epoch=1075, lrate=0.100, error=1.390
# >epoch=1076, lrate=0.100, error=1.388
# >epoch=1077, lrate=0.100, error=1.387
# >epoch=1078, lrate=0.100, error=1.385
# >epoch=1079, lrate=0.100, error=1.384
# >epoch=1080, lrate=0.100, error=1.383
# >epoch=1081, lrate=0.100, error=1.381
# >epoch=1082, lrate=0.100, error=1.380
# >epoch=1083, lrate=0.100, error=1.379
# >epoch=1084, lrate=0.100, error=1.377
# >epoch=1085, lrate=0.100, error=1.376
# >epoch=1086, lrate=0.100, error=1.375
# >epoch=1087, lrate=0.100, error=1.373
# >epoch=1088, lrate=0.100, error=1.372
# >epoch=1089, lrate=0.100, error=1.371
# >epoch=1090, lrate=0.100, error=1.369
# >epoch=1091, lrate=0.100, error=1.368
# >epoch=1092, lrate=0.100, error=1.367
# >epoch=1093, lrate=0.100, error=1.366
# >epoch=1094, lrate=0.100, error=1.364
# >epoch=1095, lrate=0.100, error=1.363
# >epoch=1096, lrate=0.100, error=1.362
# >epoch=1097, lrate=0.100, error=1.360
# >epoch=1098, lrate=0.100, error=1.359
# >epoch=1099, lrate=0.100, error=1.358
# >epoch=1100, lrate=0.100, error=1.357
# >epoch=1101, lrate=0.100, error=1.355
# >epoch=1102, lrate=0.100, error=1.354
# >epoch=1103, lrate=0.100, error=1.353
# >epoch=1104, lrate=0.100, error=1.351
# >epoch=1105, lrate=0.100, error=1.350
# >epoch=1106, lrate=0.100, error=1.349
# >epoch=1107, lrate=0.100, error=1.348
# >epoch=1108, lrate=0.100, error=1.346
# >epoch=1109, lrate=0.100, error=1.345
# >epoch=1110, lrate=0.100, error=1.344
# >epoch=1111, lrate=0.100, error=1.343
# >epoch=1112, lrate=0.100, error=1.342
# >epoch=1113, lrate=0.100, error=1.340
# >epoch=1114, lrate=0.100, error=1.339
# >epoch=1115, lrate=0.100, error=1.338
# >epoch=1116, lrate=0.100, error=1.337
# >epoch=1117, lrate=0.100, error=1.335
# >epoch=1118, lrate=0.100, error=1.334
# >epoch=1119, lrate=0.100, error=1.333
# >epoch=1120, lrate=0.100, error=1.332
# >epoch=1121, lrate=0.100, error=1.331
# >epoch=1122, lrate=0.100, error=1.329
# >epoch=1123, lrate=0.100, error=1.328
# >epoch=1124, lrate=0.100, error=1.327
# >epoch=1125, lrate=0.100, error=1.326
# >epoch=1126, lrate=0.100, error=1.325
# >epoch=1127, lrate=0.100, error=1.323
# >epoch=1128, lrate=0.100, error=1.322
# >epoch=1129, lrate=0.100, error=1.321
# >epoch=1130, lrate=0.100, error=1.320
# >epoch=1131, lrate=0.100, error=1.319
# >epoch=1132, lrate=0.100, error=1.317
# >epoch=1133, lrate=0.100, error=1.316
# >epoch=1134, lrate=0.100, error=1.315
# >epoch=1135, lrate=0.100, error=1.314
# >epoch=1136, lrate=0.100, error=1.313
# >epoch=1137, lrate=0.100, error=1.312
# >epoch=1138, lrate=0.100, error=1.311
# >epoch=1139, lrate=0.100, error=1.309
# >epoch=1140, lrate=0.100, error=1.308
# >epoch=1141, lrate=0.100, error=1.307
# >epoch=1142, lrate=0.100, error=1.306
# >epoch=1143, lrate=0.100, error=1.305
# >epoch=1144, lrate=0.100, error=1.304
# >epoch=1145, lrate=0.100, error=1.303
# >epoch=1146, lrate=0.100, error=1.301
# >epoch=1147, lrate=0.100, error=1.300
# >epoch=1148, lrate=0.100, error=1.299
# >epoch=1149, lrate=0.100, error=1.298
# >epoch=1150, lrate=0.100, error=1.297
# >epoch=1151, lrate=0.100, error=1.296
# >epoch=1152, lrate=0.100, error=1.295
# >epoch=1153, lrate=0.100, error=1.294
# >epoch=1154, lrate=0.100, error=1.292
# >epoch=1155, lrate=0.100, error=1.291
# >epoch=1156, lrate=0.100, error=1.290
# >epoch=1157, lrate=0.100, error=1.289
# >epoch=1158, lrate=0.100, error=1.288
# >epoch=1159, lrate=0.100, error=1.287
# >epoch=1160, lrate=0.100, error=1.286
# >epoch=1161, lrate=0.100, error=1.285
# >epoch=1162, lrate=0.100, error=1.284
# >epoch=1163, lrate=0.100, error=1.283
# >epoch=1164, lrate=0.100, error=1.282
# >epoch=1165, lrate=0.100, error=1.280
# >epoch=1166, lrate=0.100, error=1.279
# >epoch=1167, lrate=0.100, error=1.278
# >epoch=1168, lrate=0.100, error=1.277
# >epoch=1169, lrate=0.100, error=1.276
# >epoch=1170, lrate=0.100, error=1.275
# >epoch=1171, lrate=0.100, error=1.274
# >epoch=1172, lrate=0.100, error=1.273
# >epoch=1173, lrate=0.100, error=1.272
# >epoch=1174, lrate=0.100, error=1.271
# >epoch=1175, lrate=0.100, error=1.270
# >epoch=1176, lrate=0.100, error=1.269
# >epoch=1177, lrate=0.100, error=1.268
# >epoch=1178, lrate=0.100, error=1.267
# >epoch=1179, lrate=0.100, error=1.266
# >epoch=1180, lrate=0.100, error=1.265
# >epoch=1181, lrate=0.100, error=1.264
# >epoch=1182, lrate=0.100, error=1.262
# >epoch=1183, lrate=0.100, error=1.261
# >epoch=1184, lrate=0.100, error=1.260
# >epoch=1185, lrate=0.100, error=1.259
# >epoch=1186, lrate=0.100, error=1.258
# >epoch=1187, lrate=0.100, error=1.257
# >epoch=1188, lrate=0.100, error=1.256
# >epoch=1189, lrate=0.100, error=1.255
# >epoch=1190, lrate=0.100, error=1.254
# >epoch=1191, lrate=0.100, error=1.253
# >epoch=1192, lrate=0.100, error=1.252
# >epoch=1193, lrate=0.100, error=1.251
# >epoch=1194, lrate=0.100, error=1.250
# >epoch=1195, lrate=0.100, error=1.249
# >epoch=1196, lrate=0.100, error=1.248
# >epoch=1197, lrate=0.100, error=1.247
# >epoch=1198, lrate=0.100, error=1.246
# >epoch=1199, lrate=0.100, error=1.245
# >epoch=1200, lrate=0.100, error=1.244
# >epoch=1201, lrate=0.100, error=1.243
# >epoch=1202, lrate=0.100, error=1.242
# >epoch=1203, lrate=0.100, error=1.241
# >epoch=1204, lrate=0.100, error=1.240
# >epoch=1205, lrate=0.100, error=1.239
# >epoch=1206, lrate=0.100, error=1.238
# >epoch=1207, lrate=0.100, error=1.237
# >epoch=1208, lrate=0.100, error=1.236
# >epoch=1209, lrate=0.100, error=1.235
# >epoch=1210, lrate=0.100, error=1.234
# >epoch=1211, lrate=0.100, error=1.234
# >epoch=1212, lrate=0.100, error=1.233
# >epoch=1213, lrate=0.100, error=1.232
# >epoch=1214, lrate=0.100, error=1.231
# >epoch=1215, lrate=0.100, error=1.230
# >epoch=1216, lrate=0.100, error=1.229
# >epoch=1217, lrate=0.100, error=1.228
# >epoch=1218, lrate=0.100, error=1.227
# >epoch=1219, lrate=0.100, error=1.226
# >epoch=1220, lrate=0.100, error=1.225
# >epoch=1221, lrate=0.100, error=1.224
# >epoch=1222, lrate=0.100, error=1.223
# >epoch=1223, lrate=0.100, error=1.222
# >epoch=1224, lrate=0.100, error=1.221
# >epoch=1225, lrate=0.100, error=1.220
# >epoch=1226, lrate=0.100, error=1.219
# >epoch=1227, lrate=0.100, error=1.218
# >epoch=1228, lrate=0.100, error=1.217
# >epoch=1229, lrate=0.100, error=1.216
# >epoch=1230, lrate=0.100, error=1.216
# >epoch=1231, lrate=0.100, error=1.215
# >epoch=1232, lrate=0.100, error=1.214
# >epoch=1233, lrate=0.100, error=1.213
# >epoch=1234, lrate=0.100, error=1.212
# >epoch=1235, lrate=0.100, error=1.211
# >epoch=1236, lrate=0.100, error=1.210
# >epoch=1237, lrate=0.100, error=1.209
# >epoch=1238, lrate=0.100, error=1.208
# >epoch=1239, lrate=0.100, error=1.207
# >epoch=1240, lrate=0.100, error=1.206
# >epoch=1241, lrate=0.100, error=1.205
# >epoch=1242, lrate=0.100, error=1.205
# >epoch=1243, lrate=0.100, error=1.204
# >epoch=1244, lrate=0.100, error=1.203
# >epoch=1245, lrate=0.100, error=1.202
# >epoch=1246, lrate=0.100, error=1.201
# >epoch=1247, lrate=0.100, error=1.200
# >epoch=1248, lrate=0.100, error=1.199
# >epoch=1249, lrate=0.100, error=1.198
# >epoch=1250, lrate=0.100, error=1.197
# >epoch=1251, lrate=0.100, error=1.197
# >epoch=1252, lrate=0.100, error=1.196
# >epoch=1253, lrate=0.100, error=1.195
# >epoch=1254, lrate=0.100, error=1.194
# >epoch=1255, lrate=0.100, error=1.193
# >epoch=1256, lrate=0.100, error=1.192
# >epoch=1257, lrate=0.100, error=1.191
# >epoch=1258, lrate=0.100, error=1.190
# >epoch=1259, lrate=0.100, error=1.189
# >epoch=1260, lrate=0.100, error=1.189
# >epoch=1261, lrate=0.100, error=1.188
# >epoch=1262, lrate=0.100, error=1.187
# >epoch=1263, lrate=0.100, error=1.186
# >epoch=1264, lrate=0.100, error=1.185
# >epoch=1265, lrate=0.100, error=1.184
# >epoch=1266, lrate=0.100, error=1.183
# >epoch=1267, lrate=0.100, error=1.183
# >epoch=1268, lrate=0.100, error=1.182
# >epoch=1269, lrate=0.100, error=1.181
# >epoch=1270, lrate=0.100, error=1.180
# >epoch=1271, lrate=0.100, error=1.179
# >epoch=1272, lrate=0.100, error=1.178
# >epoch=1273, lrate=0.100, error=1.177
# >epoch=1274, lrate=0.100, error=1.177
# >epoch=1275, lrate=0.100, error=1.176
# >epoch=1276, lrate=0.100, error=1.175
# >epoch=1277, lrate=0.100, error=1.174
# >epoch=1278, lrate=0.100, error=1.173
# >epoch=1279, lrate=0.100, error=1.172
# >epoch=1280, lrate=0.100, error=1.172
# >epoch=1281, lrate=0.100, error=1.171
# >epoch=1282, lrate=0.100, error=1.170
# >epoch=1283, lrate=0.100, error=1.169
# >epoch=1284, lrate=0.100, error=1.168
# >epoch=1285, lrate=0.100, error=1.167
# >epoch=1286, lrate=0.100, error=1.167
# >epoch=1287, lrate=0.100, error=1.166
# >epoch=1288, lrate=0.100, error=1.165
# >epoch=1289, lrate=0.100, error=1.164
# >epoch=1290, lrate=0.100, error=1.163
# >epoch=1291, lrate=0.100, error=1.163
# ...
# >epoch=19604, lrate=0.100, error=0.220
# >epoch=19605, lrate=0.100, error=0.220
# >epoch=19606, lrate=0.100, error=0.220
# >epoch=19607, lrate=0.100, error=0.220
# >epoch=19608, lrate=0.100, error=0.220
# >epoch=19609, lrate=0.100, error=0.220
# >epoch=19610, lrate=0.100, error=0.220
# >epoch=19611, lrate=0.100, error=0.220
# >epoch=19612, lrate=0.100, error=0.220
# >epoch=19613, lrate=0.100, error=0.220
# >epoch=19614, lrate=0.100, error=0.220
# >epoch=19615, lrate=0.100, error=0.220
# >epoch=19616, lrate=0.100, error=0.220
# >epoch=19617, lrate=0.100, error=0.220
# >epoch=19618, lrate=0.100, error=0.220
# >epoch=19619, lrate=0.100, error=0.220
# >epoch=19620, lrate=0.100, error=0.220
# >epoch=19621, lrate=0.100, error=0.220
# >epoch=19622, lrate=0.100, error=0.220
# >epoch=19623, lrate=0.100, error=0.220
# >epoch=19624, lrate=0.100, error=0.220
# >epoch=19625, lrate=0.100, error=0.220
# >epoch=19626, lrate=0.100, error=0.220
# >epoch=19627, lrate=0.100, error=0.219
# >epoch=19628, lrate=0.100, error=0.219
# >epoch=19629, lrate=0.100, error=0.219
# >epoch=19630, lrate=0.100, error=0.219
# >epoch=19631, lrate=0.100, error=0.219
# >epoch=19632, lrate=0.100, error=0.219
# >epoch=19633, lrate=0.100, error=0.219
# >epoch=19634, lrate=0.100, error=0.219
# >epoch=19635, lrate=0.100, error=0.219
# >epoch=19636, lrate=0.100, error=0.219
# >epoch=19637, lrate=0.100, error=0.219
# >epoch=19638, lrate=0.100, error=0.219
# >epoch=19639, lrate=0.100, error=0.219
# >epoch=19640, lrate=0.100, error=0.219
# >epoch=19641, lrate=0.100, error=0.219
# >epoch=19642, lrate=0.100, error=0.219
# >epoch=19643, lrate=0.100, error=0.219
# >epoch=19644, lrate=0.100, error=0.219
# >epoch=19645, lrate=0.100, error=0.219
# >epoch=19646, lrate=0.100, error=0.219
# >epoch=19647, lrate=0.100, error=0.219
# >epoch=19648, lrate=0.100, error=0.219
# >epoch=19649, lrate=0.100, error=0.219
# >epoch=19650, lrate=0.100, error=0.219
# >epoch=19651, lrate=0.100, error=0.219
# >epoch=19652, lrate=0.100, error=0.219
# >epoch=19653, lrate=0.100, error=0.219
# >epoch=19654, lrate=0.100, error=0.219
# >epoch=19655, lrate=0.100, error=0.219
# >epoch=19656, lrate=0.100, error=0.219
# >epoch=19657, lrate=0.100, error=0.219
# >epoch=19658, lrate=0.100, error=0.219
# >epoch=19659, lrate=0.100, error=0.219
# >epoch=19660, lrate=0.100, error=0.219
# >epoch=19661, lrate=0.100, error=0.219
# >epoch=19662, lrate=0.100, error=0.219
# >epoch=19663, lrate=0.100, error=0.219
# >epoch=19664, lrate=0.100, error=0.219
# >epoch=19665, lrate=0.100, error=0.219
# >epoch=19666, lrate=0.100, error=0.219
# >epoch=19667, lrate=0.100, error=0.219
# >epoch=19668, lrate=0.100, error=0.219
# >epoch=19669, lrate=0.100, error=0.219
# >epoch=19670, lrate=0.100, error=0.219
# >epoch=19671, lrate=0.100, error=0.219
# >epoch=19672, lrate=0.100, error=0.219
# >epoch=19673, lrate=0.100, error=0.219
# >epoch=19674, lrate=0.100, error=0.219
# >epoch=19675, lrate=0.100, error=0.219
# >epoch=19676, lrate=0.100, error=0.219
# >epoch=19677, lrate=0.100, error=0.219
# >epoch=19678, lrate=0.100, error=0.219
# >epoch=19679, lrate=0.100, error=0.219
# >epoch=19680, lrate=0.100, error=0.219
# >epoch=19681, lrate=0.100, error=0.219
# >epoch=19682, lrate=0.100, error=0.219
# >epoch=19683, lrate=0.100, error=0.219
# >epoch=19684, lrate=0.100, error=0.219
# >epoch=19685, lrate=0.100, error=0.219
# >epoch=19686, lrate=0.100, error=0.219
# >epoch=19687, lrate=0.100, error=0.219
# >epoch=19688, lrate=0.100, error=0.219
# >epoch=19689, lrate=0.100, error=0.219
# >epoch=19690, lrate=0.100, error=0.219
# >epoch=19691, lrate=0.100, error=0.219
# >epoch=19692, lrate=0.100, error=0.219
# >epoch=19693, lrate=0.100, error=0.219
# >epoch=19694, lrate=0.100, error=0.219
# >epoch=19695, lrate=0.100, error=0.219
# >epoch=19696, lrate=0.100, error=0.219
# >epoch=19697, lrate=0.100, error=0.219
# >epoch=19698, lrate=0.100, error=0.219
# >epoch=19699, lrate=0.100, error=0.219
# >epoch=19700, lrate=0.100, error=0.219
# >epoch=19701, lrate=0.100, error=0.219
# >epoch=19702, lrate=0.100, error=0.219
# >epoch=19703, lrate=0.100, error=0.219
# >epoch=19704, lrate=0.100, error=0.219
# >epoch=19705, lrate=0.100, error=0.219
# >epoch=19706, lrate=0.100, error=0.219
# >epoch=19707, lrate=0.100, error=0.219
# >epoch=19708, lrate=0.100, error=0.219
# >epoch=19709, lrate=0.100, error=0.219
# >epoch=19710, lrate=0.100, error=0.219
# >epoch=19711, lrate=0.100, error=0.219
# >epoch=19712, lrate=0.100, error=0.219
# >epoch=19713, lrate=0.100, error=0.219
# >epoch=19714, lrate=0.100, error=0.219
# >epoch=19715, lrate=0.100, error=0.219
# >epoch=19716, lrate=0.100, error=0.219
# >epoch=19717, lrate=0.100, error=0.219
# >epoch=19718, lrate=0.100, error=0.219
# >epoch=19719, lrate=0.100, error=0.219
# >epoch=19720, lrate=0.100, error=0.219
# >epoch=19721, lrate=0.100, error=0.219
# >epoch=19722, lrate=0.100, error=0.219
# >epoch=19723, lrate=0.100, error=0.219
# >epoch=19724, lrate=0.100, error=0.219
# >epoch=19725, lrate=0.100, error=0.219
# >epoch=19726, lrate=0.100, error=0.219
# >epoch=19727, lrate=0.100, error=0.219
# >epoch=19728, lrate=0.100, error=0.219
# >epoch=19729, lrate=0.100, error=0.219
# >epoch=19730, lrate=0.100, error=0.219
# >epoch=19731, lrate=0.100, error=0.219
# >epoch=19732, lrate=0.100, error=0.219
# >epoch=19733, lrate=0.100, error=0.219
# >epoch=19734, lrate=0.100, error=0.219
# >epoch=19735, lrate=0.100, error=0.219
# >epoch=19736, lrate=0.100, error=0.219
# >epoch=19737, lrate=0.100, error=0.219
# >epoch=19738, lrate=0.100, error=0.219
# >epoch=19739, lrate=0.100, error=0.219
# >epoch=19740, lrate=0.100, error=0.219
# >epoch=19741, lrate=0.100, error=0.219
# >epoch=19742, lrate=0.100, error=0.219
# >epoch=19743, lrate=0.100, error=0.219
# >epoch=19744, lrate=0.100, error=0.219
# >epoch=19745, lrate=0.100, error=0.219
# >epoch=19746, lrate=0.100, error=0.219
# >epoch=19747, lrate=0.100, error=0.219
# >epoch=19748, lrate=0.100, error=0.219
# >epoch=19749, lrate=0.100, error=0.219
# >epoch=19750, lrate=0.100, error=0.219
# >epoch=19751, lrate=0.100, error=0.219
# >epoch=19752, lrate=0.100, error=0.219
# >epoch=19753, lrate=0.100, error=0.219
# >epoch=19754, lrate=0.100, error=0.219
# >epoch=19755, lrate=0.100, error=0.219
# >epoch=19756, lrate=0.100, error=0.219
# >epoch=19757, lrate=0.100, error=0.219
# >epoch=19758, lrate=0.100, error=0.219
# >epoch=19759, lrate=0.100, error=0.219
# >epoch=19760, lrate=0.100, error=0.219
# >epoch=19761, lrate=0.100, error=0.219
# >epoch=19762, lrate=0.100, error=0.219
# >epoch=19763, lrate=0.100, error=0.219
# >epoch=19764, lrate=0.100, error=0.219
# >epoch=19765, lrate=0.100, error=0.219
# >epoch=19766, lrate=0.100, error=0.219
# >epoch=19767, lrate=0.100, error=0.219
# >epoch=19768, lrate=0.100, error=0.219
# >epoch=19769, lrate=0.100, error=0.219
# >epoch=19770, lrate=0.100, error=0.219
# >epoch=19771, lrate=0.100, error=0.219
# >epoch=19772, lrate=0.100, error=0.219
# >epoch=19773, lrate=0.100, error=0.219
# >epoch=19774, lrate=0.100, error=0.219
# >epoch=19775, lrate=0.100, error=0.219
# >epoch=19776, lrate=0.100, error=0.219
# >epoch=19777, lrate=0.100, error=0.219
# >epoch=19778, lrate=0.100, error=0.219
# >epoch=19779, lrate=0.100, error=0.219
# >epoch=19780, lrate=0.100, error=0.219
# >epoch=19781, lrate=0.100, error=0.219
# >epoch=19782, lrate=0.100, error=0.219
# >epoch=19783, lrate=0.100, error=0.219
# >epoch=19784, lrate=0.100, error=0.219
# >epoch=19785, lrate=0.100, error=0.219
# >epoch=19786, lrate=0.100, error=0.219
# >epoch=19787, lrate=0.100, error=0.219
# >epoch=19788, lrate=0.100, error=0.219
# >epoch=19789, lrate=0.100, error=0.219
# >epoch=19790, lrate=0.100, error=0.219
# >epoch=19791, lrate=0.100, error=0.219
# >epoch=19792, lrate=0.100, error=0.219
# >epoch=19793, lrate=0.100, error=0.219
# >epoch=19794, lrate=0.100, error=0.219
# >epoch=19795, lrate=0.100, error=0.219
# >epoch=19796, lrate=0.100, error=0.219
# >epoch=19797, lrate=0.100, error=0.219
# >epoch=19798, lrate=0.100, error=0.219
# >epoch=19799, lrate=0.100, error=0.219
# >epoch=19800, lrate=0.100, error=0.218
# >epoch=19801, lrate=0.100, error=0.218
# >epoch=19802, lrate=0.100, error=0.218
# >epoch=19803, lrate=0.100, error=0.218
# >epoch=19804, lrate=0.100, error=0.218
# >epoch=19805, lrate=0.100, error=0.218
# >epoch=19806, lrate=0.100, error=0.218
# >epoch=19807, lrate=0.100, error=0.218
# >epoch=19808, lrate=0.100, error=0.218
# >epoch=19809, lrate=0.100, error=0.218
# >epoch=19810, lrate=0.100, error=0.218
# >epoch=19811, lrate=0.100, error=0.218
# >epoch=19812, lrate=0.100, error=0.218
# >epoch=19813, lrate=0.100, error=0.218
# >epoch=19814, lrate=0.100, error=0.218
# >epoch=19815, lrate=0.100, error=0.218
# >epoch=19816, lrate=0.100, error=0.218
# >epoch=19817, lrate=0.100, error=0.218
# >epoch=19818, lrate=0.100, error=0.218
# >epoch=19819, lrate=0.100, error=0.218
# >epoch=19820, lrate=0.100, error=0.218
# >epoch=19821, lrate=0.100, error=0.218
# >epoch=19822, lrate=0.100, error=0.218
# >epoch=19823, lrate=0.100, error=0.218
# >epoch=19824, lrate=0.100, error=0.218
# >epoch=19825, lrate=0.100, error=0.218
# >epoch=19826, lrate=0.100, error=0.218
# >epoch=19827, lrate=0.100, error=0.218
# >epoch=19828, lrate=0.100, error=0.218
# >epoch=19829, lrate=0.100, error=0.218
# >epoch=19830, lrate=0.100, error=0.218
# >epoch=19831, lrate=0.100, error=0.218
# >epoch=19832, lrate=0.100, error=0.218
# >epoch=19833, lrate=0.100, error=0.218
# >epoch=19834, lrate=0.100, error=0.218
# >epoch=19835, lrate=0.100, error=0.218
# >epoch=19836, lrate=0.100, error=0.218
# >epoch=19837, lrate=0.100, error=0.218
# >epoch=19838, lrate=0.100, error=0.218
# >epoch=19839, lrate=0.100, error=0.218
# >epoch=19840, lrate=0.100, error=0.218
# >epoch=19841, lrate=0.100, error=0.218
# >epoch=19842, lrate=0.100, error=0.218
# >epoch=19843, lrate=0.100, error=0.218
# >epoch=19844, lrate=0.100, error=0.218
# >epoch=19845, lrate=0.100, error=0.218
# >epoch=19846, lrate=0.100, error=0.218
# >epoch=19847, lrate=0.100, error=0.218
# >epoch=19848, lrate=0.100, error=0.218
# >epoch=19849, lrate=0.100, error=0.218
# >epoch=19850, lrate=0.100, error=0.218
# >epoch=19851, lrate=0.100, error=0.218
# >epoch=19852, lrate=0.100, error=0.218
# >epoch=19853, lrate=0.100, error=0.218
# >epoch=19854, lrate=0.100, error=0.218
# >epoch=19855, lrate=0.100, error=0.218
# >epoch=19856, lrate=0.100, error=0.218
# >epoch=19857, lrate=0.100, error=0.218
# >epoch=19858, lrate=0.100, error=0.218
# >epoch=19859, lrate=0.100, error=0.218
# >epoch=19860, lrate=0.100, error=0.218
# >epoch=19861, lrate=0.100, error=0.218
# >epoch=19862, lrate=0.100, error=0.218
# >epoch=19863, lrate=0.100, error=0.218
# >epoch=19864, lrate=0.100, error=0.218
# >epoch=19865, lrate=0.100, error=0.218
# >epoch=19866, lrate=0.100, error=0.218
# >epoch=19867, lrate=0.100, error=0.218
# >epoch=19868, lrate=0.100, error=0.218
# >epoch=19869, lrate=0.100, error=0.218
# >epoch=19870, lrate=0.100, error=0.218
# >epoch=19871, lrate=0.100, error=0.218
# >epoch=19872, lrate=0.100, error=0.218
# >epoch=19873, lrate=0.100, error=0.218
# >epoch=19874, lrate=0.100, error=0.218
# >epoch=19875, lrate=0.100, error=0.218
# >epoch=19876, lrate=0.100, error=0.218
# >epoch=19877, lrate=0.100, error=0.218
# >epoch=19878, lrate=0.100, error=0.218
# >epoch=19879, lrate=0.100, error=0.218
# >epoch=19880, lrate=0.100, error=0.218
# >epoch=19881, lrate=0.100, error=0.218
# >epoch=19882, lrate=0.100, error=0.218
# >epoch=19883, lrate=0.100, error=0.218
# >epoch=19884, lrate=0.100, error=0.218
# >epoch=19885, lrate=0.100, error=0.218
# >epoch=19886, lrate=0.100, error=0.218
# >epoch=19887, lrate=0.100, error=0.218
# >epoch=19888, lrate=0.100, error=0.218
# >epoch=19889, lrate=0.100, error=0.218
# >epoch=19890, lrate=0.100, error=0.218
# >epoch=19891, lrate=0.100, error=0.218
# >epoch=19892, lrate=0.100, error=0.218
# >epoch=19893, lrate=0.100, error=0.218
# >epoch=19894, lrate=0.100, error=0.218
# >epoch=19895, lrate=0.100, error=0.218
# >epoch=19896, lrate=0.100, error=0.218
# >epoch=19897, lrate=0.100, error=0.218
# >epoch=19898, lrate=0.100, error=0.218
# >epoch=19899, lrate=0.100, error=0.218
# >epoch=19900, lrate=0.100, error=0.218
# >epoch=19901, lrate=0.100, error=0.218
# >epoch=19902, lrate=0.100, error=0.218
# >epoch=19903, lrate=0.100, error=0.218
# >epoch=19904, lrate=0.100, error=0.218
# >epoch=19905, lrate=0.100, error=0.218
# >epoch=19906, lrate=0.100, error=0.218
# >epoch=19907, lrate=0.100, error=0.218
# >epoch=19908, lrate=0.100, error=0.218
# >epoch=19909, lrate=0.100, error=0.218
# >epoch=19910, lrate=0.100, error=0.218
# >epoch=19911, lrate=0.100, error=0.218
# >epoch=19912, lrate=0.100, error=0.218
# >epoch=19913, lrate=0.100, error=0.218
# >epoch=19914, lrate=0.100, error=0.218
# >epoch=19915, lrate=0.100, error=0.218
# >epoch=19916, lrate=0.100, error=0.218
# >epoch=19917, lrate=0.100, error=0.218
# >epoch=19918, lrate=0.100, error=0.218
# >epoch=19919, lrate=0.100, error=0.218
# >epoch=19920, lrate=0.100, error=0.218
# >epoch=19921, lrate=0.100, error=0.218
# >epoch=19922, lrate=0.100, error=0.218
# >epoch=19923, lrate=0.100, error=0.218
# >epoch=19924, lrate=0.100, error=0.218
# >epoch=19925, lrate=0.100, error=0.218
# >epoch=19926, lrate=0.100, error=0.218
# >epoch=19927, lrate=0.100, error=0.218
# >epoch=19928, lrate=0.100, error=0.218
# >epoch=19929, lrate=0.100, error=0.218
# >epoch=19930, lrate=0.100, error=0.218
# >epoch=19931, lrate=0.100, error=0.218
# >epoch=19932, lrate=0.100, error=0.218
# >epoch=19933, lrate=0.100, error=0.218
# >epoch=19934, lrate=0.100, error=0.218
# >epoch=19935, lrate=0.100, error=0.218
# >epoch=19936, lrate=0.100, error=0.218
# >epoch=19937, lrate=0.100, error=0.218
# >epoch=19938, lrate=0.100, error=0.218
# >epoch=19939, lrate=0.100, error=0.218
# >epoch=19940, lrate=0.100, error=0.218
# >epoch=19941, lrate=0.100, error=0.218
# >epoch=19942, lrate=0.100, error=0.218
# >epoch=19943, lrate=0.100, error=0.218
# >epoch=19944, lrate=0.100, error=0.218
# >epoch=19945, lrate=0.100, error=0.218
# >epoch=19946, lrate=0.100, error=0.218
# >epoch=19947, lrate=0.100, error=0.218
# >epoch=19948, lrate=0.100, error=0.218
# >epoch=19949, lrate=0.100, error=0.218
# >epoch=19950, lrate=0.100, error=0.218
# >epoch=19951, lrate=0.100, error=0.218
# >epoch=19952, lrate=0.100, error=0.218
# >epoch=19953, lrate=0.100, error=0.218
# >epoch=19954, lrate=0.100, error=0.218
# >epoch=19955, lrate=0.100, error=0.218
# >epoch=19956, lrate=0.100, error=0.218
# >epoch=19957, lrate=0.100, error=0.218
# >epoch=19958, lrate=0.100, error=0.218
# >epoch=19959, lrate=0.100, error=0.218
# >epoch=19960, lrate=0.100, error=0.218
# >epoch=19961, lrate=0.100, error=0.218
# >epoch=19962, lrate=0.100, error=0.218
# >epoch=19963, lrate=0.100, error=0.218
# >epoch=19964, lrate=0.100, error=0.218
# >epoch=19965, lrate=0.100, error=0.218
# >epoch=19966, lrate=0.100, error=0.218
# >epoch=19967, lrate=0.100, error=0.218
# >epoch=19968, lrate=0.100, error=0.218
# >epoch=19969, lrate=0.100, error=0.218
# >epoch=19970, lrate=0.100, error=0.218
# >epoch=19971, lrate=0.100, error=0.218
# >epoch=19972, lrate=0.100, error=0.218
# >epoch=19973, lrate=0.100, error=0.218
# >epoch=19974, lrate=0.100, error=0.218
# >epoch=19975, lrate=0.100, error=0.217
# >epoch=19976, lrate=0.100, error=0.217
# >epoch=19977, lrate=0.100, error=0.217
# >epoch=19978, lrate=0.100, error=0.217
# >epoch=19979, lrate=0.100, error=0.217
# >epoch=19980, lrate=0.100, error=0.217
# >epoch=19981, lrate=0.100, error=0.217
# >epoch=19982, lrate=0.100, error=0.217
# >epoch=19983, lrate=0.100, error=0.217
# >epoch=19984, lrate=0.100, error=0.217
# >epoch=19985, lrate=0.100, error=0.217
# >epoch=19986, lrate=0.100, error=0.217
# >epoch=19987, lrate=0.100, error=0.217
# >epoch=19988, lrate=0.100, error=0.217
# >epoch=19989, lrate=0.100, error=0.217
# >epoch=19990, lrate=0.100, error=0.217
# >epoch=19991, lrate=0.100, error=0.217
# >epoch=19992, lrate=0.100, error=0.217
# >epoch=19993, lrate=0.100, error=0.217
# >epoch=19994, lrate=0.100, error=0.217
# >epoch=19995, lrate=0.100, error=0.217
# >epoch=19996, lrate=0.100, error=0.217
# >epoch=19997, lrate=0.100, error=0.217
# >epoch=19998, lrate=0.100, error=0.217
# >epoch=19999, lrate=0.100, error=0.217
# [{'weights': [1.196097444985968, 1.1811068779017058, 0.5441382715437748], 'output': 0.9999990498895835, 'delta': -4.5096847428570915e-10}, {'weights': [2.6127822278962043, -4.003632721803539, -1.1323370928312253], 'output': 0.9923881412618475, 'delta': 1.56288175235515e-05}]
# [{'weights': [2.16273565533289, -9.105409974597862, 2.348372432394912], 'output': 0.010718996064752169, 'delta': -0.00011366529746765704}, {'weights': [-2.015060181601922, 9.105806113056822, -2.495943592847478], 'output': 0.9892862763810477, 'delta': 0.00011355411108366915}]

# %%
# 학습한 네트워크로 예측값을 뽑아보자.

def predict(network, row):
    outputs = forward_propagate(network, row)
    return outputs.index(max(outputs)) # 순전파 결과에서 어떤것이 최종 아웃풋이 되나요?

# %%
# 네트워크가 잘 학습되었는지 확인해보자. 

for row in dataset:
    prediction = predict(network, row) # 앞서 최적(학습)시킨 네트워크로 잘 학습되었는지 평가 
    print('실제값=%d, 예측값=%d' % (row[-1], prediction))
# Out:
# 실제값=0, 예측값=0
# 실제값=0, 예측값=0
# 실제값=0, 예측값=0
# 실제값=0, 예측값=0
# 실제값=0, 예측값=0
# 실제값=1, 예측값=1
# 실제값=1, 예측값=1
# 실제값=1, 예측값=1
# 실제값=1, 예측값=1
# 실제값=1, 예측값=1
